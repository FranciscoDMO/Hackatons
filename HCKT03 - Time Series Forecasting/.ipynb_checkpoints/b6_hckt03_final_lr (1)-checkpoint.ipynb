# %%
import pandas as pd

# %%
# pd.options.plotting.backend = "plotly"

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt 
from sklearn.ensemble import GradientBoostingRegressor

# %%
from tqdm import tqdm_notebook as tqdm

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error

# %%
# %matplotlib inline

# %%
 
import numpy as np
plt.rcParams['figure.figsize'] = (16, 4)

# %%
import warnings
warnings.filterwarnings(action="ignore")
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %%
from utils import * # We've added all the functions from the last BLU to the utils.py

# %%
from xgboost import XGBRegressor

# %% [markdown]
# # DATA

# %%
df = pd.read_csv("data/data.csv", index_col="date", parse_dates=True)

# %%
df
# Out:
#                      PM2.5  exog
# date
# 2013-03-01 00:00:00    4.0   4.4
# 2013-03-01 01:00:00    8.0   4.7
# 2013-03-01 02:00:00    7.0   5.6
# 2013-03-01 03:00:00    6.0   3.1
# 2013-03-01 04:00:00    3.0   2.0
# ...                    ...   ...
# 2017-02-21 19:00:00    NaN   1.4
# 2017-02-21 20:00:00    NaN   1.5
# 2017-02-21 21:00:00    NaN   1.1
# 2017-02-21 22:00:00    NaN   1.7
# 2017-02-21 23:00:00    NaN   2.0
#
# [34896 rows x 2 columns]

# %%
train = df.iloc[:-24*7]
test = df.iloc[-24*7:]

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer() # To obtain better results we may want to have more neighbors, of course that in a real setting
                       # this is a parameter that should be tunned
    
imputed_train = imputer.fit_transform(train) # This may take a bit to run
train = pd.DataFrame(imputed_train, index=train.index, columns=train.columns)

# %%
df=pd.concat([train,test], axis=0)

# %%
df
# Out:
#                      PM2.5  exog
# date
# 2013-03-01 00:00:00    4.0   4.4
# 2013-03-01 01:00:00    8.0   4.7
# 2013-03-01 02:00:00    7.0   5.6
# 2013-03-01 03:00:00    6.0   3.1
# 2013-03-01 04:00:00    3.0   2.0
# ...                    ...   ...
# 2017-02-21 19:00:00    NaN   1.4
# 2017-02-21 20:00:00    NaN   1.5
# 2017-02-21 21:00:00    NaN   1.1
# 2017-02-21 22:00:00    NaN   1.7
# 2017-02-21 23:00:00    NaN   2.0
#
# [34896 rows x 2 columns]

# %%
df = build_exog_features(df, 24*7)

# %%
train = df.iloc[:-24*7*2]
val = df.iloc[-24*7*2:-24*7]
train_val = df.iloc[:-24*7]
test = df.iloc[-24*7:]

# %% [markdown]
# # VALIDATION

# %%
train
# Out:
#                      PM2.5  exog  exog_lead1  exog_lead2  exog_lead3  \
# date
# 2013-03-01 00:00:00    4.0   4.4         4.7         5.6         3.1
# 2013-03-01 01:00:00    8.0   4.7         5.6         3.1         2.0
# 2013-03-01 02:00:00    7.0   5.6         3.1         2.0         3.7
# 2013-03-01 03:00:00    6.0   3.1         2.0         3.7         2.5
# 2013-03-01 04:00:00    3.0   2.0         3.7         2.5         3.8
# ...                    ...   ...         ...         ...         ...
# 2017-02-07 19:00:00  110.0   1.2         1.3         0.8         0.4
# 2017-02-07 20:00:00  118.0   1.3         0.8         0.4         0.0
# 2017-02-07 21:00:00  107.0   0.8         0.4         0.0         0.2
# 2017-02-07 22:00:00  106.0   0.4         0.0         0.2         0.0
# 2017-02-07 23:00:00  114.0   0.0         0.2         0.0         1.2
#
#                      exog_lead4  exog_lead5  exog_lead6  exog_lead7  \
# date
# 2013-03-01 00:00:00         2.0         3.7         2.5         3.8
# 2013-03-01 01:00:00         3.7         2.5         3.8         4.1
# 2013-03-01 02:00:00         2.5         3.8         4.1         2.6
# 2013-03-01 03:00:00         3.8         4.1         2.6         3.6
# 2013-03-01 04:00:00         4.1         2.6         3.6         3.7
# ...                         ...         ...         ...         ...
# 2017-02-07 19:00:00         0.0         0.2         0.0         1.2
# 2017-02-07 20:00:00         0.2         0.0         1.2         1.7
# 2017-02-07 21:00:00         0.0         1.2         1.7         1.6
# 2017-02-07 22:00:00         1.2         1.7         1.6         1.8
# 2017-02-07 23:00:00         1.7         1.6         1.8         1.9
#
#                      exog_lead8  ...  exog_lead159  exog_lead160  \
# date                             ...
# 2013-03-01 00:00:00         4.1  ...           3.3           1.9
# 2013-03-01 01:00:00         2.6  ...           1.9           1.4
# 2013-03-01 02:00:00         3.6  ...           1.4           1.9
# 2013-03-01 03:00:00         3.7  ...           1.9           1.5
# 2013-03-01 04:00:00         5.1  ...           1.5           1.5
# ...                         ...  ...           ...           ...
# 2017-02-07 19:00:00         1.7  ...           1.4           1.4
# 2017-02-07 20:00:00         1.6  ...           1.4           1.9
# 2017-02-07 21:00:00         1.8  ...           1.9           1.3
# 2017-02-07 22:00:00         1.9  ...           1.3           1.3
# 2017-02-07 23:00:00         1.6  ...           1.3           1.3
#
#                      exog_lead161  exog_lead162  exog_lead163  exog_lead164  \
# date
# 2013-03-01 00:00:00           1.4           1.9           1.5           1.5
# 2013-03-01 01:00:00           1.9           1.5           1.5           1.4
# 2013-03-01 02:00:00           1.5           1.5           1.4           1.3
# 2013-03-01 03:00:00           1.5           1.4           1.3           0.1
# 2013-03-01 04:00:00           1.4           1.3           0.1           0.0
# ...                           ...           ...           ...           ...
# 2017-02-07 19:00:00           1.9           1.3           1.3           1.3
# 2017-02-07 20:00:00           1.3           1.3           1.3           2.0
# 2017-02-07 21:00:00           1.3           1.3           2.0           1.7
# 2017-02-07 22:00:00           1.3           2.0           1.7           1.2
# 2017-02-07 23:00:00           2.0           1.7           1.2           1.1
#
#                      exog_lead165  exog_lead166  exog_lead167  exog_lead168
# date
# 2013-03-01 00:00:00           1.4           1.3           0.1           0.0
# 2013-03-01 01:00:00           1.3           0.1           0.0           0.9
# 2013-03-01 02:00:00           0.1           0.0           0.9           0.8
# 2013-03-01 03:00:00           0.0           0.9           0.8           0.0
# 2013-03-01 04:00:00           0.9           0.8           0.0           1.0
# ...                           ...           ...           ...           ...
# 2017-02-07 19:00:00           2.0           1.7           1.2           1.1
# 2017-02-07 20:00:00           1.7           1.2           1.1           0.2
# 2017-02-07 21:00:00           1.2           1.1           0.2           1.0
# 2017-02-07 22:00:00           1.1           0.2           1.0           1.0
# 2017-02-07 23:00:00           0.2           1.0           1.0           0.8
#
# [34560 rows x 170 columns]

# %%
predictions = predict_n_periods(series_=np.log(train+1), 
                  n_periods=24*7, 
                  model=LinearRegression(), 
                  num_periods_lagged=24*7,
                  num_periods_diffed=24,
                  weekday = True,
                  month = True,
                  hour=True,
                  holidays = False,
                  target = "PM2.5"
                  )
# Out:
# Period 1
# Fitting...
# Period 2
# Fitting...
# Period 3
# Fitting...
# Period 126
# Fitting...
# Period 127
# Fitting...
# Period 128
# Fitting...
# Period 129
# Fitting...
# Period 130
# Fitting...
# Period 131
# Fitting...
# Period 132
# Fitting...
# Period 133
# Fitting...
# Period 134
# Fitting...
# Period 135
# Fitting...
# Period 136
# Fitting...
# Period 137
# Fitting...
# Period 138
# Fitting...
# Period 139
# Fitting...
# Period 140
# Fitting...
# Period 141
# Fitting...
# Period 142
# Fitting...
# Period 143
# Fitting...
# Period 144
# Fitting...
# Period 145
# Fitting...
# Period 146
# Fitting...
# Period 147
# Fitting...
# Period 148
# Fitting...
# Period 149
# Fitting...
# Period 150
# Fitting...
# Period 151
# Fitting...
# Period 152
# Fitting...
# Period 153
# Fitting...
# Period 154
# Fitting...
# Period 155
# Fitting...
# Period 156
# Fitting...
# Period 157
# Fitting...
# Period 158
# Fitting...
# Period 159
# Fitting...
# Period 160
# Fitting...
# Period 161
# Fitting...
# Period 162
# Fitting...
# Period 163
# Fitting...
# Period 164
# Fitting...
# Period 165
# Fitting...
# Period 166
# Fitting...
# Period 167
# Fitting...
# Period 168
# Fitting...

# %%
val_mae = mean_absolute_error(val["PM2.5"],np.exp(predictions)-1)
print(val_mae)
# Out:
# 32.940026341573144

# %%
train_val.loc["2017-01-30":"2017-02-14"]["PM2.5"].plot(label="original data")
plt.ylabel('PM2.5')
pd.Series(np.exp(predictions)-1, index=val.index).plot(label="pred")
plt.title('real vs. expected')
plt.legend();

# %%
predictions_submission_log = predict_n_periods(series_=np.log(train_val+1), 
                  n_periods=24*7, 
                  model=LinearRegression(), 
                  num_periods_lagged=24*7,
                  num_periods_diffed=24,
                  weekday = True,
                  month = True,
                  hour=True,
                  holidays = False,
                  target = "PM2.5"
                  )
# Out:
# Period 1
# Fitting...
# Period 2
# Fitting...
# Period 3
# Fitting...
# Period 4
# Fitting...
# Period 5
# Fitting...
# Period 6
# Fitting...
# Period 7
# Fitting...
# Period 8
# Fitting...
# Period 9
# Fitting...
# Period 10
# Fitting...
# Period 11
# Fitting...
# Period 12
# Fitting...
# Period 13
# Fitting...
# Period 14
# Fitting...
# Period 15
# Fitting...
# Period 16
# Fitting...
# Period 17
# Fitting...
# Period 18
# Fitting...
# Period 19
# Fitting...
# Period 20
# Fitting...
# Period 21
# Fitting...
# Period 22
# Fitting...
# Period 23
# Fitting...
# Period 24
# Fitting...
# Period 25
# Fitting...
# Period 26
# Fitting...
# Period 27
# Fitting...
# Period 28
# Fitting...
# Period 29
# Fitting...
# Period 30
# Fitting...
# Period 31
# Fitting...
# Period 32
# Fitting...
# Period 33
# Fitting...
# Period 34
# Fitting...
# Period 35
# Fitting...
# Period 36
# Fitting...
# Period 37
# Fitting...
# Period 38
# Fitting...
# Period 39
# Fitting...
# Period 40
# Fitting...
# Period 41
# Fitting...
# Period 42
# Fitting...
# Period 43
# Fitting...
# Period 44
# Fitting...
# Period 45
# Fitting...
# Period 46
# Fitting...
# Period 47
# Fitting...
# Period 48
# Fitting...
# Period 49
# Fitting...
# Period 50
# Fitting...
# Period 51
# Fitting...
# Period 52
# Fitting...
# Period 53
# Fitting...
# Period 54
# Fitting...
